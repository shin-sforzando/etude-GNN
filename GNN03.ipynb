# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-sforzando/etude-GNN/blob/master/GNN03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Graph Neural Network - 03
#
# ## 概要
#
# 第3回は、Pythonでグラフ構造を扱う実践編。

# %% [markdown]
# ## 分析編

# %% [markdown]
# ### NetworkX

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.random_regular_graph(3, 10)

nx.draw_networkx(G)
plt.show()

# %% [markdown]
# ## 次回予告
#
# (T.B.D.)
